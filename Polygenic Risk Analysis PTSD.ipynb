# %%
import pandas as pd

# %%
ptsd_df= pd.read_csv("SORTED_PTSD_EA9_AA7_LA1_SA2_ALL_study_specific_PCs1.txt", sep='\t')

# %%
ptsd_df
# Out:
#                 MarkerName Allele1 Allele2  Effect  StdErr       P-value  \
# 0                rs7400289       t       c -0.2852  0.0525  5.491000e-08
# 1               rs75117028       a       c -0.3974  0.0744  9.088000e-08
# 2         chr13_70628410_D       d      i5  0.6437  0.1215  1.163000e-07
# 3              rs149585529       a       g  0.6425  0.1215  1.242000e-07
# 4              rs139558732       t       c  0.7161  0.1357  1.305000e-07
# ...                    ...     ...     ...     ...     ...           ...
# 25473722         rs9962851       c       g  0.0000  0.0262  1.000000e+00
# 25473723         rs9963321       t       c  0.0000  0.0965  1.000000e+00
# 25473724         rs9973857       t       c  0.0000  0.0267  1.000000e+00
# 25473725         rs9979848       a       g -0.0000  0.0469  1.000000e+00
# 25473726         rs9994467       a       g  0.0000  0.0519  1.000000e+00
#
#                     Direction
# 0         +------?-+-----?+--
# ...

# %%
ptsd_df_filt= ptsd_df.loc[ptsd_df['P-value']<=5e-7]

# %%
ptsd_df_filt
# Out:
#           MarkerName Allele1 Allele2  Effect  StdErr       P-value  \
# 0          rs7400289       t       c -0.2852  0.0525  5.491000e-08
# 1         rs75117028       a       c -0.3974  0.0744  9.088000e-08
# 2   chr13_70628410_D       d      i5  0.6437  0.1215  1.163000e-07
# 3        rs149585529       a       g  0.6425  0.1215  1.242000e-07
# 4        rs139558732       t       c  0.7161  0.1357  1.305000e-07
# 5        rs190485314       t       c -2.5951  0.5007  2.189000e-07
# 6         rs75169709       t       c -0.4419  0.0854  2.262000e-07
# 7         rs78516857       a       g -0.4419  0.0854  2.263000e-07
# 8          rs6673056       t       g  0.4410  0.0853  2.370000e-07
# 9   chr1_182409244_D       d      i4  0.5358  0.1048  3.166000e-07
# 10       rs138517393       t       c  1.0194  0.1999  3.411000e-07
# 11       rs139069151       a       c  0.6037  0.1186  3.543000e-07
# 12        rs78664956       t       c -0.5192  0.1020  3.584000e-07
# ...

# %%
import math

ptsd_df_filt['Possible Odds Ratio']= ptsd_df_filt.apply(lambda x: math.exp(x['Effect']), axis=1)
# Out:
# <ipython-input-8-9b395ebc31fe>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ptsd_df_filt['Possible Odds Ratio']= ptsd_df_filt.apply(lambda x: math.exp(x['Effect']), axis=1)

# %%
ptsd_df_filt
# Out:
#           MarkerName Allele1 Allele2  Effect  StdErr       P-value  \
# 0          rs7400289       t       c -0.2852  0.0525  5.491000e-08
# 1         rs75117028       a       c -0.3974  0.0744  9.088000e-08
# 2   chr13_70628410_D       d      i5  0.6437  0.1215  1.163000e-07
# 3        rs149585529       a       g  0.6425  0.1215  1.242000e-07
# 4        rs139558732       t       c  0.7161  0.1357  1.305000e-07
# 5        rs190485314       t       c -2.5951  0.5007  2.189000e-07
# 6         rs75169709       t       c -0.4419  0.0854  2.262000e-07
# 7         rs78516857       a       g -0.4419  0.0854  2.263000e-07
# 8          rs6673056       t       g  0.4410  0.0853  2.370000e-07
# 9   chr1_182409244_D       d      i4  0.5358  0.1048  3.166000e-07
# 10       rs138517393       t       c  1.0194  0.1999  3.411000e-07
# 11       rs139069151       a       c  0.6037  0.1186  3.543000e-07
# 12        rs78664956       t       c -0.5192  0.1020  3.584000e-07
# ...

# %%
schizophrenia_df = pd.read_csv("daner_natgen_eas_eur_autosomes", sep='\t')

# %%
schizophrenia_df
# Out:
#           CHR          SNP         BP A1 A2  FRQ_A_56418  FRQ_U_78818   INFO  \
# 0           8   rs62513865  101592213  T  C       0.0716       0.0750  0.956
# 1           8   rs73696507  105231413  T  C       0.9590       0.9600  0.998
# 2           8   rs79643588  106973048  A  G       0.0713       0.0743  0.990
# 3           8    rs6994300  102569817  A  G       0.0666       0.0664  0.878
# 4           8   rs17396518  108690829  T  G       0.4890       0.4910  0.981
# ...       ...          ...        ... .. ..          ...          ...    ...
# 13558618   20  rs148755306   47231076  A  G       0.0154       0.0221  0.869
# 13558619   20  rs117705259   46761380  A  G       0.0154       0.0152  0.968
# 13558620   20    rs6017602   44168957  T  C       0.0432       0.0396  0.995
# 13558621   20  rs144166091   45724327  T  C       0.9860       0.9870  0.804
# 13558622   20    rs1111021   42747689  T  C       0.2790       0.2810  0.982
#
# ...

# %%
schizophrenia_df.sort_values('P',ascending= False)
# Out:
#           CHR           SNP         BP  A1 A2  FRQ_A_56418  FRQ_U_78818  \
# 10893042    5  rs139936287m   65608563  GA  G       0.7550       0.7520
# 1051465     1     rs6683651  165647480   A  G       0.3620       0.3670
# 6069878     9     rs2456264   76258129   T  C       0.9730       0.9740
# 5186828     3   rs138551372  185446099   T  C       0.0353       0.0345
# 1910020     8     rs9650569  141141753   T  C       0.0412       0.0410
# ...       ...           ...        ...  .. ..          ...          ...
# 4564112     6    rs28360634   27332891   T  C       0.9450       0.9330
# 4597781     6    rs34724414   28619353   A  G       0.9250       0.9110
# 4535270     6    rs13194504   28630691   A  G       0.0749       0.0889
# 4553055     6     rs1233578   28712247   A  G       0.9030       0.8910
# 4587237     6     rs9257566   29144532   T  C       0.0685       0.0811
#
#            INFO       OR      SE             P  ngt Direction  HetISqt  HetDf  \
# ...

# %%
schizo_df_filt= schizophrenia_df.loc[schizophrenia_df['P']<=5e-8]

# %%
schizo_df_filt
# Out:
#           CHR         SNP         BP A1 A2  FRQ_A_56418  FRQ_U_78818   INFO  \
# 379         8   rs1434281  103671080  A  G        0.344        0.399  0.957
# 42353       8   rs4734654  103669991  A  G        0.656        0.601  0.959
# 99597      16   rs4949087   64333546  A  G        0.354        0.393  0.958
# 99851      16  rs34707355   64375453  T  C        0.357        0.396  0.954
# 100535     16   rs9933980   64370514  T  G        0.356        0.396  0.957
# ...       ...         ...        ... .. ..          ...          ...    ...
# 13394708    2   rs3736594   27995781  A  C        0.380        0.386  0.964
# 13531911   20    rs495146   48130328  T  C        0.303        0.341  0.961
# 13534498   20   rs7267348   48131036  T  C        0.703        0.663  0.961
# 13535893   20   rs6019879   48130628  T  C        0.703        0.663  0.961
# 13537154   20   rs7271624   48129169  C  G        0.741        0.753  0.997
#
# ...

# %%
schizo_df_filt.sort_values('OR',ascending= False)
# Out:
#          CHR            SNP        BP A1     A2  FRQ_A_56418  FRQ_U_78818  \
# 4553688    6  chr6:26518757  26518757  A      T      0.99300       0.9910
# 4584146    6    rs114476648  27633802  T      C      0.98100       0.9790
# 4802236    6  chr6:30332254  30332254  T      C      0.97300       0.9700
# 4565589    6     rs71559051  27799470  A      G      0.94500       0.9350
# 4559282    6    rs113780580  27555056  A  AACAC      0.94100       0.9300
# ...      ...            ...       ... ..    ...          ...          ...
# 4553584    6     rs71557345  26680698  A      G      0.06170       0.0734
# 4537686    6    rs192804591  27729706  A      T      0.06370       0.0756
# 4543692    6     rs35202262  27799514  T      C      0.06460       0.0766
# 4597569    6  chr6:27244243  27244243  T      C      0.02760       0.0311
# 4763487    6    rs114486118  30346826  T      C      0.00894       0.0104
#
#           INFO       OR      SE             P  ngt Direction  HetISqt  HetDf  \
# ...

# %%
schizo_df_filt.head(30)
# Out:
#         CHR         SNP         BP A1  A2  FRQ_A_56418  FRQ_U_78818   INFO  \
# 379       8   rs1434281  103671080  A   G        0.344        0.399  0.957
# 42353     8   rs4734654  103669991  A   G        0.656        0.601  0.959
# 99597    16   rs4949087   64333546  A   G        0.354        0.393  0.958
# 99851    16  rs34707355   64375453  T   C        0.357        0.396  0.954
# 100535   16   rs9933980   64370514  T   G        0.356        0.396  0.957
# 101159   16   rs9934855   64326532  T   C        0.646        0.607  0.957
# 101491   16   rs2917691   64297994  T   C        0.570        0.553  0.959
# 101607   16   rs2917690   64297917  T   G        0.428        0.445  0.956
# 101648   16   rs2917695   64299409  C   G        0.584        0.571  0.995
# 102242   16  rs11643828   64349345  A   T        0.325        0.339  0.994
# 103280   16  rs12930453   64315466  C   G        0.322        0.335  0.990
# ...

# %%
schizo_df_filt[schizo_df_filt['SNP']=="rs6461049"]
# Out:
#          CHR        SNP       BP A1 A2  FRQ_A_56418  FRQ_U_78818   INFO  \
# 3061760    7  rs6461049  2017445  T  C        0.542        0.536  0.961
#
#               OR      SE             P  ngt Direction  HetISqt  HetDf  HetPVa  \
# 3061760  1.07691  0.0088  2.582000e-17   22  ++-+++++      0.0      7  0.6336
#
#            Nca    Nco      Neff
# 3061760  56418  78818  64441.44

# %%
schizo_snps= pd.read_csv("schizophrenia_snps.txt", sep='\t', names=['SNP'])

# %%
schizo_snps
# Out:
#            SNP
# 0    rs6461049
# 1    rs7085104
# 2    rs1198588
# 3    rs1006737
# 4   rs17691888
# 5    rs4129585
# 6   rs10789369
# 7     rs794086
# 8     rs290542
# 9    rs2373000
# 10   rs6878284
# 11   rs4687552
# 12  rs12991836
# 13   rs2949006
# 14   rs4801131
# 15    rs778371
# 16     rs14403
# 17  rs11532322
# 18   rs1538774
# 19  rs11995572
# 20    rs171748
# 21   rs2910032

# %%
schizo_df_final= schizo_df_filt.merge(schizo_snps, on="SNP")

# %%
schizo_df_final.sort_values('CHR',ascending=True)

# %%
# %%bash
#
# #awk '$2 == "rs121907970" {print $2}' 1000Genomes/ALL.chr15.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz
# #bgzip -d /datasets/cs284-sp21-A00-public/1000Genomes/ALL.chr15.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz -c > ~/teams/CSE284_SP21_A00/team13/chr15.vcf
# bcftools view --include ID==@ts_snps.list chr15.vcf| cut -f 1-4
#
# ##/rs387906309//rs147324677//rs76173977//rs138058578//rs121907970/
# Out:
# Process is interrupted.

# %%
#vcf_df = pd.read_csv("1000Genomes/ALL.chr15.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz", sep='\t', error_bad_lines=False)

# import os
# filename = "1000Genomes/ALL.chr15.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.vcf.gz"
# lines_number = sum(1 for line in open(filename))
# lines_in_chunk = 200
# counter = 0
# completed = 0
# reader = pd.read_csv(filename, chunksize=lines_in_chunk, sep='\t', error_bad_lines=False )
# for chunk in reader:
#     # < ... reading the chunk somehow... >
#     # showing progress:
#     counter += lines_in_chunk
#     new_completed = int(round(float(counter)/lines_number * 100))
#     if (new_completed > completed): 
#         completed = new_completed
#         print("Completed", completed, "%")

# %%
chr15_df = pd.read_csv("chr15_HG00379_HG00155.txt", sep='\t', error_bad_lines=False, skiprows=2, names=['CHROM', 'SNP', 'REF', 'ALT', 'PARENT1', 'PARENT2', 'USELESS', 'CHILD'] )

# %%
chr15_df
# Out:
#         CHROM          SNP   REF ALT PARENT1 PARENT2  USELESS CHILD
# 15   20000041  rs371549847     T   A     0|0     0|0      NaN   0|0
# 15   20000075  rs565090028     C   T     0|0     0|0      NaN   0|0
# 15   20000114  rs201219124     G   T     0|0     0|0      NaN   0|0
# 15   20000123  rs373298708     T   C     0|0     0|0      NaN   0|0
# 15   20000127  rs560310552     A   T     0|0     0|0      NaN   0|0
# ..        ...          ...   ...  ..     ...     ...      ...   ...
# 15  102520995  rs543980749    CG   C     0|0     0|0      NaN   0|0
# 15  102521010  rs533757656     G   C     0|0     0|0      NaN   0|0
# 15  102521041  rs548966424     A   G     0|0     0|0      NaN   0|0
# 15  102521057  rs567278523     G   C     0|0     0|0      NaN   0|0
# 15  102521131  rs141255594  GGTT   G     0|1     0|1      NaN   1|1
#
# [2424689 rows x 8 columns]

# %%
chr15_df = chr15_df.drop('USELESS', axis=1)
# Out:
#         CHROM          SNP   REF ALT PARENT1 PARENT2 CHILD
# 15   20000041  rs371549847     T   A     0|0     0|0   0|0
# 15   20000075  rs565090028     C   T     0|0     0|0   0|0
# 15   20000114  rs201219124     G   T     0|0     0|0   0|0
# 15   20000123  rs373298708     T   C     0|0     0|0   0|0
# 15   20000127  rs560310552     A   T     0|0     0|0   0|0
# ..        ...          ...   ...  ..     ...     ...   ...
# 15  102520995  rs543980749    CG   C     0|0     0|0   0|0
# 15  102521010  rs533757656     G   C     0|0     0|0   0|0
# 15  102521041  rs548966424     A   G     0|0     0|0   0|0
# 15  102521057  rs567278523     G   C     0|0     0|0   0|0
# 15  102521131  rs141255594  GGTT   G     0|1     0|1   1|1
#
# [2424689 rows x 7 columns]

# %%
ts_snp = chr15_df.loc[chr15_df['SNP']=="rs76173977"]

# %%
ts_snp
# Out:
#        CHROM         SNP REF ALT PARENT1 PARENT2  USELESS CHILD
# 15  72640388  rs76173977   C   T     0|0     0|0      NaN   0|0

# %%
chr17_df = pd.read_csv("chr17_HG00379_HG00155.txt", sep='\t', error_bad_lines=False, skiprows=2, names=['CHROM', 'SNP', 'REF', 'ALT', 'PARENT1', 'PARENT2', 'USELESS', 'CHILD'] )
chr17_df = chr17_df.drop('USELESS', axis=1)
adhd_snp = chr17_df.loc[chr17_df['SNP']=="rs8079781"]
adhd_snp
# Out:
#        CHROM        SNP REF ALT PARENT1 PARENT2 CHILD
# 17  79050148  rs8079781   C   T     0|1     0|0   0|0

# %%
chr22_df = pd.read_csv("chr22_HG00379_HG00155.txt", sep='\t', error_bad_lines=False, skiprows=2, names=['CHROM', 'SNP', 'REF', 'ALT', 'PARENT1', 'PARENT2', 'USELESS', 'CHILD'] )
chr22_df = chr22_df.drop('USELESS', axis=1)
neuro_snp = chr22_df.loc[chr22_df['SNP']=="rs189150283"]
neuro_snp
# Out:
# Empty DataFrame
# Columns: [CHROM, SNP, REF, ALT, PARENT1, PARENT2, CHILD]
# Index: []

# %%
chr1_df = pd.read_csv("chr1_HG00379_HG00155.txt", sep='\t', error_bad_lines=False, skiprows=2, names=['CHROM', 'SNP', 'REF', 'ALT', 'PARENT1', 'PARENT2', 'USELESS', 'CHILD'] )
chr1_df = chr1_df.drop('USELESS', axis=1)
neuro_snp = chr1_df.loc[chr1_df['SNP']=="rs4660761"]
neuro_snp
# Out:
#       CHROM        SNP REF ALT PARENT1 PARENT2 CHILD
# 1  44440146  rs4660761   G   A     0|1     1|1   0|1

# %%
chr15_df = pd.read_csv("chr15_HG00379_HG00155.txt", sep='\t', error_bad_lines=False, skiprows=2, names=['CHROM','BP', 'SNP', 'REF', 'ALT', 'PARENT1', 'PARENT2', 'USELESS', 'CHILD','EXTRA'], index_col=False )

# %%
chr15_df
# Out:
#          CHROM         BP          SNP   REF ALT PARENT1 PARENT2  USELESS  \
# 0           15   20000041  rs371549847     T   A     0|0     0|0      NaN
# 1           15   20000075  rs565090028     C   T     0|0     0|0      NaN
# 2           15   20000114  rs201219124     G   T     0|0     0|0      NaN
# 3           15   20000123  rs373298708     T   C     0|0     0|0      NaN
# 4           15   20000127  rs560310552     A   T     0|0     0|0      NaN
# ...        ...        ...          ...   ...  ..     ...     ...      ...
# 2424684     15  102520995  rs543980749    CG   C     0|0     0|0      NaN
# 2424685     15  102521010  rs533757656     G   C     0|0     0|0      NaN
# 2424686     15  102521041  rs548966424     A   G     0|0     0|0      NaN
# 2424687     15  102521057  rs567278523     G   C     0|0     0|0      NaN
# 2424688     15  102521131  rs141255594  GGTT   G     0|1     0|1      NaN
#
#         CHILD  EXTRA
# 0         0|0    NaN
# 1         0|0    NaN
# ...
